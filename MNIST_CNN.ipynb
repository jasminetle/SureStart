# %%
#Loads the MNIST dataset & Create first 9 images in training dataset

# example of loading the mnist dataset
from keras.datasets import mnist
from matplotlib import pyplot
# load dataset
(trainX, trainY), (testX, testY) = mnist.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainY.shape))
print('Test: X=%s, y=%s' % (testX.shape, testY.shape))
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
# plot first few images
for i in range(9):
    # define subplot
    pyplot.subplot(330 + 1 + i)
    # plot raw pixel data
    pyplot.imshow(trainX[i], cmap=pyplot.get_cmap('gray'))
    
#display figure
pyplot.show()

# %%
# reshape dataset to have a single channel

trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
testX = testX.reshape((testX.shape[0], 28, 28, 1))

# %%
# one hot encode target value
from keras.utils import to_categorical
trainY = to_categorical(trainY)
testY = to_categorical(testY)

# %%
# normalize the pixel values of graysacale images
# 1) converting the data type 
# 2) dividing pixel values by the max value

# convert from integers to floats
trainX_norm = trainX.astype('float32')
testX_norm = testX.astype('float32')
# normalize to range 0-1
trainX_norm = trainX_norm / 255.0
testX_norm = testX_norm / 255.0

# %%
#Split data into training and validation set
from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(trainX_norm, trainY, test_size = 0.1, random_state=20)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Dropout, Flatten, MaxPooling2D, Dense
from keras.optimizers import RMSprop, Adam, SGD
#Define CNN model

#Initialize model
model = Sequential()

#First input layer
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))

#Pooling Layer
model.add(MaxPooling2D((2, 2)))

#Dropout Layer
model.add(Dropout(0.20))

#Flattening Layer
model.add(Flatten())

#Dense Layers
model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(10, activation='softmax'))

#display model
model.summary() 

# compile model
opt = SGD(lr=0.01, momentum=0.9)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 5408)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               540900
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 542,230
# Trainable params: 542,230
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the Model 
history = model.fit(X_train, Y_train, batch_size = 250, 
          epochs = 50, verbose = 1, validation_data = (X_val, Y_val),
          steps_per_epoch = X_train.shape[0] // 250)
# Out:
# Epoch 1/50
# 216/216 [==============================] - 16s 71ms/step - loss: 0.6565 - accuracy: 0.7936 - val_loss: 0.1709 - val_accuracy: 0.9517
# Epoch 2/50
# 216/216 [==============================] - 13s 62ms/step - loss: 0.1776 - accuracy: 0.9477 - val_loss: 0.1257 - val_accuracy: 0.9648
# Epoch 3/50
# 216/216 [==============================] - 14s 63ms/step - loss: 0.1218 - accuracy: 0.9640 - val_loss: 0.0973 - val_accuracy: 0.9738
# Epoch 4/50
# 216/216 [==============================] - 14s 66ms/step - loss: 0.0958 - accuracy: 0.9726 - val_loss: 0.0818 - val_accuracy: 0.9770
# Epoch 5/50
# 216/216 [==============================] - 15s 68ms/step - loss: 0.0795 - accuracy: 0.9771 - val_loss: 0.0716 - val_accuracy: 0.9795
# Epoch 6/50
# 216/216 [==============================] - 14s 65ms/step - loss: 0.0679 - accuracy: 0.9798 - val_loss: 0.0668 - val_accuracy: 0.9810
# Epoch 7/50
# 216/216 [==============================] - 13s 60ms/step - loss: 0.0630 - accuracy: 0.9811 - val_loss: 0.0631 - val_accuracy: 0.9832
# Epoch 8/50
# 216/216 [==============================] - 13s 62ms/step - loss: 0.0558 - accuracy: 0.9833 - val_loss: 0.0626 - val_accuracy: 0.9808
# Epoch 9/50
# 216/216 [==============================] - 15s 68ms/step - loss: 0.0487 - accuracy: 0.9853 - val_loss: 0.0557 - val_accuracy: 0.9838
# Epoch 10/50
# 216/216 [==============================] - 13s 58ms/step - loss: 0.0448 - accuracy: 0.9869 - val_loss: 0.0528 - val_accuracy: 0.9852
# Epoch 11/50
# 216/216 [==============================] - 15s 68ms/step - loss: 0.0408 - accuracy: 0.9882 - val_loss: 0.0519 - val_accuracy: 0.9848
# Epoch 12/50
# 216/216 [==============================] - 12s 56ms/step - loss: 0.0412 - accuracy: 0.9872 - val_loss: 0.0494 - val_accuracy: 0.9858
# Epoch 13/50
# 216/216 [==============================] - 14s 66ms/step - loss: 0.0328 - accuracy: 0.9906 - val_loss: 0.0483 - val_accuracy: 0.9848
# Epoch 14/50
# 216/216 [==============================] - 14s 65ms/step - loss: 0.0315 - accuracy: 0.9909 - val_loss: 0.0461 - val_accuracy: 0.9867
# Epoch 15/50
# 216/216 [==============================] - 13s 62ms/step - loss: 0.0307 - accuracy: 0.9916 - val_loss: 0.0507 - val_accuracy: 0.9843
# Epoch 16/50
# 216/216 [==============================] - 14s 64ms/step - loss: 0.0296 - accuracy: 0.9914 - val_loss: 0.0457 - val_accuracy: 0.9870
# Epoch 17/50
# 216/216 [==============================] - 14s 65ms/step - loss: 0.0278 - accuracy: 0.9913 - val_loss: 0.0458 - val_accuracy: 0.9857
# Epoch 18/50
# 216/216 [==============================] - 13s 61ms/step - loss: 0.0260 - accuracy: 0.9924 - val_loss: 0.0441 - val_accuracy: 0.9865
# Epoch 19/50
# 216/216 [==============================] - 13s 61ms/step - loss: 0.0241 - accuracy: 0.9930 - val_loss: 0.0469 - val_accuracy: 0.9865
# Epoch 20/50
# 216/216 [==============================] - 13s 62ms/step - loss: 0.0239 - accuracy: 0.9929 - val_loss: 0.0452 - val_accuracy: 0.9870
# Epoch 21/50
# 216/216 [==============================] - 14s 64ms/step - loss: 0.0215 - accuracy: 0.9938 - val_loss: 0.0437 - val_accuracy: 0.9867
# Epoch 22/50
# 216/216 [==============================] - 14s 65ms/step - loss: 0.0204 - accuracy: 0.9943 - val_loss: 0.0434 - val_accuracy: 0.9880
# Epoch 23/50
# 216/216 [==============================] - 12s 55ms/step - loss: 0.0204 - accuracy: 0.9939 - val_loss: 0.0430 - val_accuracy: 0.9883
# Epoch 24/50
# 216/216 [==============================] - 12s 55ms/step - loss: 0.0183 - accuracy: 0.9945 - val_loss: 0.0415 - val_accuracy: 0.9887
# Epoch 25/50
# 216/216 [==============================] - 11s 52ms/step - loss: 0.0165 - accuracy: 0.9955 - val_loss: 0.0422 - val_accuracy: 0.9880
# Epoch 26/50
# 216/216 [==============================] - 11s 52ms/step - loss: 0.0172 - accuracy: 0.9953 - val_loss: 0.0428 - val_accuracy: 0.9882
# Epoch 27/50
# 216/216 [==============================] - 11s 52ms/step - loss: 0.0171 - accuracy: 0.9952 - val_loss: 0.0417 - val_accuracy: 0.9888
# Epoch 28/50
# 216/216 [==============================] - 11s 52ms/step - loss: 0.0153 - accuracy: 0.9961 - val_loss: 0.0416 - val_accuracy: 0.9872
# Epoch 29/50
# 216/216 [==============================] - 11s 51ms/step - loss: 0.0141 - accuracy: 0.9961 - val_loss: 0.0417 - val_accuracy: 0.9887
# Epoch 30/50
# 216/216 [==============================] - 13s 61ms/step - loss: 0.0153 - accuracy: 0.9961 - val_loss: 0.0412 - val_accuracy: 0.9878
# Epoch 31/50
# 216/216 [==============================] - 11s 51ms/step - loss: 0.0134 - accuracy: 0.9967 - val_loss: 0.0420 - val_accuracy: 0.9885
# Epoch 32/50
# 216/216 [==============================] - 11s 52ms/step - loss: 0.0134 - accuracy: 0.9964 - val_loss: 0.0410 - val_accuracy: 0.9883
# Epoch 33/50
# 216/216 [==============================] - 11s 52ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 0.0415 - val_accuracy: 0.9885
# Epoch 34/50
# 216/216 [==============================] - 11s 51ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.0406 - val_accuracy: 0.9883
# Epoch 35/50
# 216/216 [==============================] - 11s 51ms/step - loss: 0.0117 - accuracy: 0.9969 - val_loss: 0.0394 - val_accuracy: 0.9888
# Epoch 36/50
# 216/216 [==============================] - 11s 51ms/step - loss: 0.0102 - accuracy: 0.9974 - val_loss: 0.0414 - val_accuracy: 0.9877
# Epoch 37/50
# 216/216 [==============================] - 12s 55ms/step - loss: 0.0106 - accuracy: 0.9973 - val_loss: 0.0406 - val_accuracy: 0.9883
# Epoch 38/50
# 216/216 [==============================] - 13s 60ms/step - loss: 0.0101 - accuracy: 0.9977 - val_loss: 0.0414 - val_accuracy: 0.9880
# Epoch 39/50
# 216/216 [==============================] - 14s 63ms/step - loss: 0.0096 - accuracy: 0.9976 - val_loss: 0.0417 - val_accuracy: 0.9880
# Epoch 40/50
# 216/216 [==============================] - 13s 60ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.0398 - val_accuracy: 0.9888
# Epoch 41/50
# 216/216 [==============================] - 15s 68ms/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.0398 - val_accuracy: 0.9887
# Epoch 42/50
# 216/216 [==============================] - 15s 68ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 0.0402 - val_accuracy: 0.9887
# Epoch 43/50
# 216/216 [==============================] - 14s 67ms/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.0396 - val_accuracy: 0.9885
# Epoch 44/50
# 216/216 [==============================] - 13s 62ms/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.0414 - val_accuracy: 0.9878
# Epoch 45/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.0405 - val_accuracy: 0.9890
# Epoch 46/50
# 216/216 [==============================] - 13s 58ms/step - loss: 0.0083 - accuracy: 0.9983 - val_loss: 0.0414 - val_accuracy: 0.9880
# Epoch 47/50
# 216/216 [==============================] - 14s 63ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.0398 - val_accuracy: 0.9892
# Epoch 48/50
# 216/216 [==============================] - 12s 56ms/step - loss: 0.0070 - accuracy: 0.9983 - val_loss: 0.0415 - val_accuracy: 0.9883
# Epoch 49/50
# 216/216 [==============================] - 13s 62ms/step - loss: 0.0078 - accuracy: 0.9978 - val_loss: 0.0423 - val_accuracy: 0.9878
# Epoch 50/50
# 216/216 [==============================] - 13s 59ms/step - loss: 0.0064 - accuracy: 0.9987 - val_loss: 0.0416 - val_accuracy: 0.9890

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'], color='tab:purple')
plt.plot(history.history['val_accuracy'], color='g')
plt.title('Classification Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['training', 'test'], loc='best')
plt.show()

plt.plot(history.history['loss'], color='tab:purple')
plt.plot(history.history['val_loss'], color='g')
plt.title('Cross Entropy Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['training', 'test'], loc='best')
plt.show()

# %%
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix

#Confusion matrix: Used to evaluate how well the model is predicting our test dataset

# predict the values from the test dataset
Y_pred = model.predict(testX_norm)

# convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 

# convert test observations to one hot vectors
Y_true = np.argmax(testY,axis = 1) 

# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 

# plot the confusion matrix
f,ax = plt.subplots(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
